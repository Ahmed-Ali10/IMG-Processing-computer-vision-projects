# %%
import cv2
import numpy as np
import numpy
import cv2 as cv


    
# importing library for plotting
from matplotlib import pyplot as plt
import matplotlib.pylab as pl

# %% [markdown]
# import cv2
# import numpy as np
# import numpy
# import cv2 as cv
#
#
#
#  importing library for plotting
# from matplotlib import pyplot as plt
# import matplotlib.pylab as pl

# %%
# reads an input image
img = cv2.imread('messii.png',0)
img+=20  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
img = cv2.imread('messi.jpg',0)
plt.hist(img.ravel(), 256, [0, 256], cumulative=(True))
# Out:
# (array([   4262.,    7431.,   10934.,   15348.,   20598.,   26833.,
#           33989.,   41978.,   50639.,   59818.,   69595.,   79671.,
#           89982.,  100502.,  111226.,  122055.,  133238.,  144475.,
#          156084.,  168064.,  180030.,  192400.,  204734.,  217564.,
#          230303.,  243332.,  256426.,  269806.,  283135.,  296539.,
#          310018.,  323615.,  337145.,  350467.,  363999.,  377659.,
#          391056.,  404653.,  418211.,  431642.,  445133.,  458625.,
#          472076.,  485653.,  499337.,  512452.,  525806.,  539245.,
#          552647.,  566039.,  579377.,  592722.,  606127.,  619309.,
#          632483.,  645692.,  658787.,  671867.,  684824.,  697745.,
#          710518.,  723351.,  736089.,  748659.,  760931.,  773229.,
#          785281.,  797385.,  809281.,  821042.,  832708.,  844142.,
#          855415.,  866421.,  877187.,  888054.,  898601.,  908974.,
#          919162.,  929235.,  939054.,  948547.,  957935.,  967209.,
# ...

# %%
img = cv.imread('messi.jpg',0)
equ = cv.equalizeHist(img)
res1 = np.hstack((img,equ)) #stacking images side-by-side
cv.imwrite('res1.png',res)
# Out:
# True

# %%
plt.plot(res1)
plt.show()

# %%
plt.hist(res1.ravel(), 256, [0, 256], cumulative=(True))
# Out:
# (array([   8524.,   18365.,   26282.,   35946.,   47431.,   60822.,
#           67978.,   83956.,  101278.,  110457.,  129413.,  149266.,
#          159577.,  180173.,  190897.,  212037.,  223220.,  244977.,
#          256586.,  279290.,  291256.,  314455.,  326789.,  350802.,
#          363541.,  387807.,  400901.,  425890.,  439219.,  464603.,
#          478082.,  503645.,  517175.,  542867.,  556399.,  582393.,
#          595790.,  622217.,  635775.,  649206.,  675436.,  688928.,
#          715408.,  728985.,  755763.,  768878.,  782232.,  809051.,
#          822453.,  849174.,  862512.,  889261.,  902666.,  915848.,
#          942501.,  955710.,  982402.,  995482., 1021969., 1034890.,
#         1047663., 1073818., 1086556., 1112658., 1124930., 1137228.,
#         1162940., 1175044., 1200337., 1212098., 1237361., 1248795.,
#         1260068., 1284632., 1295398., 1319696., 1330243., 1354107.,
#         1364295., 1374368., 1397679., 1407172., 1430011., 1439285.,
# ...

# %%
plt.imshow(res1, cmap="gray")`

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('ta.jpg',0)

sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
sobelz=sobelx+sobely
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])

plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
